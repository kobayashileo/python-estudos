# %% [markdown]
# # Exercícios
#
# São exercícios bem parecidos com os que fizemos com listas. Mas na tupla, podemos não só trabalhar com índices, mas fazer o "unpacking" das tuplas, o que pode facilitar nossos códigos.
#
# ## 1. Análise de Vendas
#
# Nesse exercício vamos fazer uma "análise simples" de atingimento de Meta.
#
# Temos uma lista com os vendedores e os valores de vendas e queremos identificar (printar) quais os vendedores que bateram a meta e qual foi o valor que eles venderam.

# %%
meta = 10000
vendas = [
    ('João', 15000),
    ('Julia', 27000),
    ('Marcus', 9900),
    ('Maria', 3750),
    ('Ana', 10300),
    ('Alon', 7870),
]


for venda in vendas:
    vendedor, qtde_vendas = venda
    if qtde_vendas >= meta:
        print(f'O vendedor {vendedor} bateu a meta com {qtde_vendas} vendas!!')
    else:
        print(f'O vendedor {vendedor} não bateu a meta, com {qtde_vendas} vendas!')
# Out:
# O vendedor João bateu a meta com 15000 vendas!!
# O vendedor Julia bateu a meta com 27000 vendas!!
# O vendedor Marcus não bateu a meta, com 9900 vendas!
# O vendedor Maria não bateu a meta, com 3750 vendas!
# O vendedor Ana bateu a meta com 10300 vendas!!
# O vendedor Alon não bateu a meta, com 7870 vendas!

# %% [markdown]
# ## 2. Comparação com Ano Anterior
#
# Digamos que você está analisando as vendas de produtos de um ecommerce e quer identificar quais produtos tiveram no ano de 2020 mais vendas do que no ano de 2019, para reportar isso para a diretoria.
#
# Sua resposta pode ser um print de cada produto, qual foi a venda de 2019, a venda de 2020 e o % de crescimento de 2020 para 2019.
#
# Lembrando, para calcular o % de crescimento de um produto de um ano para o outro, podemos fazer: (vendas_produto2020/vendas_produto2019 - 1)
#
# A lógica da tupla é: (produto, vendas2019, vendas2020)

# %%
vendas_produtos = [('iphone', 558147, 951642), ('galaxy', 712350, 244295), ('ipad', 573823, 26964), ('tv', 405252, 787604), ('máquina de café', 718654, 867660), ('kindle', 531580, 78830), ('geladeira', 973139, 710331), ('adega', 892292, 646016), ('notebook dell', 422760, 694913), ('notebook hp', 154753, 539704), ('notebook asus', 887061, 324831), ('microsoft surface', 438508, 667179), ('webcam', 237467, 295633), ('caixa de som', 489705, 725316), ('microfone', 328311, 644622), ('câmera canon', 591120, 994303)]

#seu código aqui
for produto in vendas_produtos:
    nome, qtde_2019, qtde_2020 = produto
    crescimento = qtde_2020 / qtde_2019 - 1
    if crescimento > 0:
        print('O produto {} vendeu {} unidades em 2019 e {} unidades em 2020, tendo um crescimento de {:.2%}% !!!'
            .format(nome, qtde_2019, qtde_2020, crescimento))
    else: 
        print('O produto {} vendeu {} unidades em 2019 e {} unidades em 2020, tendo uma queda de {:.2%} !!!'
            .format(nome, qtde_2019, qtde_2020, abs(crescimento)))
# Out:
# O produto iphone vendeu 558147 unidades em 2019 e 951642 unidades em 2020, tendo um crescimento de 70.50%% !!!
# O produto galaxy vendeu 712350 unidades em 2019 e 244295 unidades em 2020, tendo uma queda de 65.71% !!!
# O produto ipad vendeu 573823 unidades em 2019 e 26964 unidades em 2020, tendo uma queda de 95.30% !!!
# O produto tv vendeu 405252 unidades em 2019 e 787604 unidades em 2020, tendo um crescimento de 94.35%% !!!
# O produto máquina de café vendeu 718654 unidades em 2019 e 867660 unidades em 2020, tendo um crescimento de 20.73%% !!!
# O produto kindle vendeu 531580 unidades em 2019 e 78830 unidades em 2020, tendo uma queda de 85.17% !!!
# O produto geladeira vendeu 973139 unidades em 2019 e 710331 unidades em 2020, tendo uma queda de 27.01% !!!
# O produto adega vendeu 892292 unidades em 2019 e 646016 unidades em 2020, tendo uma queda de 27.60% !!!
# O produto notebook dell vendeu 422760 unidades em 2019 e 694913 unidades em 2020, tendo um crescimento de 64.38%% !!!
# ...
